# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("holdings_data.csv", index_col = 0)
df.head()
# Out:
#                   ABB        AAPL         BLK         DFS        EOG  \
# Date
# 2022-01-03  38.470001  182.009995  911.729980  118.639999  91.160004
# 2022-01-04  39.000000  179.699997  917.219971  122.300003  95.349998
# 2022-01-05  38.430000  174.919998  891.770020  120.639999  93.599998
# 2022-01-06  38.270000  172.000000  895.489990  122.820000  95.519997
# 2022-01-07  38.099998  172.169998  892.270020  125.690002  98.160004
#
#                     HD         JPM   KGC       MBUU         MCD         MDT  \
# Date
# 2022-01-03  408.640015  161.699997  5.66  69.690002  268.579987  106.099998
# 2022-01-04  412.839996  167.830002  5.69  68.550003  268.510010  106.389999
# 2022-01-05  407.239990  163.779999  5.60  66.730003  267.190002  106.010002
# 2022-01-06  405.760010  165.520004  5.36  69.870003  269.690002  104.970001
# 2022-01-07  393.609985  167.160004  5.45  67.099998  267.059998  105.160004
#
#                   MSFT        NVDA         PTC        REGN          SE  \
# ...

# %%
df[["ABB", "AAPL", "BLK", "DFS", "EOG", "HD", "JPM", "KGC", "MBUU", "MCD", "MDT", "MSFT", "NVDA", "PTC", "REGN", "SE", "SRE", "SOFI", "UNH", "VLD"]].plot(figsize = (24,10))
plt.grid()
plt.title("All Stocks")
plt.show()

# %%
del close_df[Adj Close]
