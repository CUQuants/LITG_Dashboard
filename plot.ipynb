# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("holdings_data.csv", index_col = 0)
df.head()
# Out:
#                 FundValue
# Date
# 2022-04-25  360298.952320
# 2022-04-26  353454.789597
# 2022-04-27  355204.541110
# 2022-04-28  361655.330753
# 2022-04-29  355271.157586

# %%
df["Holdings1"] = df["FundValue"]-156054.73
df[["Holdings1"]].plot(figsize = (24,10))
plt.grid()
plt.title("Holdings1")
plt.show()

# %%
df[["FundValue"]].plot(figsize = (24,10))
plt.grid()
plt.title("Total Fund Value")
plt.show()
